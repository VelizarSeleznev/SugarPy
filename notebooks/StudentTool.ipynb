# %% [markdown]
# # SugarPy Student Tool
#
# Use the widgets below to create math functions and balance chemistry reactions.

# %%
from sugarpy.widgets import function_builder, balance_widget
function_builder()

# %%
balance_widget()

# %%
find_hypothenuse(3, 4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 find_hypothenuse(3, 4)
#
# NameError: name 'find_hypothenuse' is not defined
